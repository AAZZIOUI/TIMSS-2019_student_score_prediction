# %%
import pandas as pd
import config # a python file that contains path to TIMSS data files
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ml_data_1 = pd.read_csv(config.ml_data_1, index_col=False)
x = ml_data_1.drop(columns='mean_PV')
x.sample()
# Out:
#      BSBG05D                                      BSBG04         BSBG13E  \
# 4317      No  Enough to fill one bookcase (26–100 books)  Agree a little
#
#              BSBG13D BSBG14A         BSBM16A         BSBM17D       BSBM18C  \
# 4317  Agree a little   Never  Agree a little  Agree a little  Some lessons
#
#              BSBM20E         BSBM20I
# 4317  Agree a little  Agree a little

# %%
from kmodes.kmodes import KModes

# %%
cost = []
k = range(1,10)
for num_clusters in list(k):
    # will test init = 'random' , init = 'Huang'
    kmode_clusters = KModes(n_clusters = num_clusters , init = "Huang", n_init = 5, verbose=1 )
    kmode_clusters.fit_predict(x)
    cost.append(kmode_clusters.cost_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 39723.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 39723.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 39723.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 39723.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 39723.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1359, cost: 34722.0
# Run 1, iteration: 2/100, moves: 809, cost: 34722.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# ...

# %%
plt.plot(k, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title("Elbow Method For Optimal number of clusters")
plt.show()

# %% [markdown]
# Optimal number of clusters using 'Huang' algorithm seems to be 5 or 6 clusters
